# %% [markdown]
# <a href="https://colab.research.google.com/github/DrAlexSanz/Image-SR/blob/master/Mid_Unet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# This notebook implements the deeper UNET architecture. It is applied as a denoising autoencoder as an intermediate way to work on the "deblurrer" and the image super-resolution.
#
# It works on a 300x300 patch of images taken from the flickr 8k dataset. I could have done it for bigger images but I can only run this on colab because my computer is what it is. On the other hand, 300x300 is a reasonable size, it's small enough to run in a reasonable time but it's big enough for a realistic problem. It's one order of magnitude bigger in each dimension than the mnist equivalent (what I called small unet). It also has the advantage that the dataset fits in memory and I don't have to develop a custom Image data generator. This is the next thing I will do.

# %% [markdown]
# First import things that I will need and a bit more that I may need later.

# %%
import numpy as np
import os, shutil
from keras import backend as K
from keras.layers import Input, Dense, Conv2D, MaxPooling2D, UpSampling2D, Add, BatchNormalization, Concatenate, Conv2DTranspose, ZeroPadding2D, Cropping2D
from keras.models import Model, load_model
from keras.utils import plot_model
from keras.optimizers import Adam, Adadelta, Adagrad
from keras.callbacks import History, ModelCheckpoint
import matplotlib.pyplot as plt
import glob
import cv2
from PIL import Image

K.set_image_data_format("channels_last")
# Out:
# Using TensorFlow backend.

# %% [markdown]
# Get the auxiliary functions that I developed from my colab.

# %%
# !wget https://raw.githubusercontent.com/DrAlexSanz/Image-SR/master/big_UNET.py
from big_UNET import *
# Out:
# --2019-10-08 09:47:35--  https://raw.githubusercontent.com/DrAlexSanz/Image-SR/master/big_UNET.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5572 (5.4K) [text/plain]
# Saving to: ‘big_UNET.py’
#
# big_UNET.py         100%[===================>]   5.44K  --.-KB/s    in 0s
#
# 2019-10-08 09:47:35 (56.2 MB/s) - ‘big_UNET.py’ saved [5572/5572]

# %% [markdown]
# Mount my google drive to access my dataset.

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount = True)
# Out:
# Mounted at /content/drive

# %% [markdown]
# As I said, the function loads the dataset into a numpy vector (tensor). It takes the picture, crops a 300x300 patch from it and saves it in the X array. The patch is always the top left corner, as explained inside, for simplicity. Could be randomly taken and I will probably implement this in the Data Generator. In any case, the patch is big enough to capture a reasonable proportion of the image. Not a lot of information is lost. This function is not the fastest one, but I only run it the first time and then I save the vector. Loading the array is very fast. Comment or uncomment the lines below as needed.

# %%
path_flickr = "/content/drive/My Drive/flickr"
X = load_imgs_to_array(path_flickr)

# np.save("./pic.npy", x_list) For future use if it gets to that.

# %%
# np.save("/content/drive/My Drive/Image-SR/pic.npy", X)

# %%
X = np.load("/content/drive/My Drive/Image-SR/pic.npy") # Very fast once it is created

# %% [markdown]
# Make sure I loaded what I wanted to load.

# %%
np.array(X).shape
# Out:
# (600, 300, 300, 3)

# %% [markdown]
# Make the train, test and validation datasets. The dataset is already random as far as I can see looking at the pictures. I take the first 400 pictures as train set, then 100 as a test set and the last 100 as a validation set, to predict.
#
# Some people may argue that 400 pictures are not too many. I could do more, of course, but then it takes longer to run. As I said, I wanted to find a compromise between a realistic training set and a fast one. I don't get anything from having the script run for two weeks.

# %%
X_train = X[:400, :, :] # Remember, this takes from 0 to 799, 800 is taken in the next one
X_val = X[400:500, :, :] # Math notation = [a, b)
X_test = X[500:600, :, :]

# %% [markdown]
# Make sure I split the data properly.

# %%
X_train.shape
# Out:
# (400, 300, 300, 3)

# %% [markdown]
# Thake the ground truths and add the noise to create the inputs. I think 0.5 as a factor is reasonable. It's random gaussian noise (not blurr) that is added to the picture. After normalizing and adding the noise I clip it at 1 just for a better convergence. It should converge also If I skip this step but this will most likely make it faster.

# %%
X_train = X_train.astype("float32")
X_test = X_test.astype("float32")
X_val = X_val.astype("float32")

X_train = X_train/255
X_test = X_test/255
X_val = X_val/255


noise_fact = 0.5

X_noisy_train = X_train + noise_fact * np.random.normal(loc = 0, scale = 1, size = X_train.shape)
X_noisy_test = X_test + noise_fact * np.random.normal(loc = 0, scale = 1, size = X_test.shape)
X_noisy_val = X_val + noise_fact * np.random.normal(loc = 0, scale = 1, size = X_val.shape)

X_noisy_train = np.clip(X_noisy_train, 0, 1)
X_noisy_test = np.clip(X_noisy_test, 0, 1)
X_noisy_val = np.clip(X_noisy_val, 0, 1)

# Free memory
del X

# %% [markdown]
# I will show a few images to check that everything works.

# %%
n = 5
plot_some_pics(n, X_noisy_train)

# %% [markdown]
# I define the magnitudes of the different tensor dimensions and call the definition function. Plot the summary.
#
# In the definition, the BatchNorm layers are commented out. I found out that they don't result on a significant improvement on convergence. Therefore leaving them active won't be too advantageous.

# %%
width = X_train.shape[1]
height = X_train.shape[2]
n_channels = X_train.shape[3]

big_u = Big_UNET(width, height, n_channels)
big_u.summary()
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 300, 300, 3)  0
# __________________________________________________________________________________________________
# C1 (Conv2D)                     (None, 300, 300, 64) 1792        input_1[0][0]
# __________________________________________________________________________________________________
# C2 (Conv2D)                     (None, 150, 150, 128 73856       C1[0][0]
# __________________________________________________________________________________________________
# C3 (Conv2D)                     (None, 75, 75, 256)  295168      C2[0][0]
# __________________________________________________________________________________________________
# C4 (Conv2D)                     (None, 38, 38, 512)  3277312     C3[0][0]
# __________________________________________________________________________________________________
# C5 (Conv2D)                     (None, 19, 19, 512)  2359808     C4[0][0]
# __________________________________________________________________________________________________
# Encoded (Conv2D)                (None, 19, 19, 512)  262656      C5[0][0]
# __________________________________________________________________________________________________
# C5T (Conv2DTranspose)           (None, 38, 38, 256)  1179904     Encoded[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 38, 38, 768)  0           C5T[0][0]
#                                                                  C4[0][0]
# __________________________________________________________________________________________________
# C4T (Conv2DTranspose)           (None, 76, 76, 256)  1769728     concatenate_1[0][0]
# __________________________________________________________________________________________________
# cropping2d_1 (Cropping2D)       (None, 75, 75, 256)  0           C4T[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 75, 75, 512)  0           cropping2d_1[0][0]
#                                                                  C3[0][0]
# __________________________________________________________________________________________________
# C3T (Conv2DTranspose)           (None, 150, 150, 128 589952      concatenate_2[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 150, 150, 256 0           C3T[0][0]
#                                                                  C2[0][0]
# __________________________________________________________________________________________________
# C2T (Conv2DTranspose)           (None, 300, 300, 64) 147520      concatenate_3[0][0]
# __________________________________________________________________________________________________
# C0T (Conv2D)                    (None, 300, 300, 3)  1731        C2T[0][0]
# ==================================================================================================
# Total params: 9,959,427
# Trainable params: 9,959,427
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# Plot the model to see that my connections are correct. They seem to be ok.

# %%
plot_model(big_u, to_file = "Big_Unet.png",show_shapes = True)

# %% [markdown]
# Train the model. Add the history and checkpoint callbacks. I don't want to lose 1 h of training if the session runs out. The history will be used later to plot the training process.
#
# As optimizer use Adadelta. For some reason Adam and Adagrad are not as efficient. They tend to stagnate for several iterations. The default parameters work ok with a 0.05 learning rate.
#
# I set the number of iterations to 200 or 300. You need about 200 to start seeing something reasonable in the predicted images. At the beginning they are mostly grey.
#
# As a loss function MSE is better in this case. Binary Crossentropy is ok too but there is a drawback, the function is not symmetric. Looking at the definition:
#
# $L = -\sum p\cdot log(p)$
#
# The log function is not symmetric, which translates into a general assymetry of the , so the side in which I iterate will make a difference. Besides, since I want to rebuild the picture, MSE or even MAE seem more correct from the conceptual point of view. Ideally, all the pixels would be the same after the training process.

# %%
opti = Adadelta(lr = 0.05)
hist = History()
path_save = "/content/drive/My Drive/Image-SR/big_u_{epoch:04d}.h5" #the current one
checkpointer = ModelCheckpoint(path_save, period = 25, save_best_only = True, save_weights_only = True)
big_u.compile(optimizer = opti, loss = "mean_squared_error")
num_it = 300
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
big_u.load_weights("/content/drive/My Drive/Image-SR/big_u_0200.h5")
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:197: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.

# %% [markdown]
# Now I train the model.

# %%
big_u.fit(X_noisy_train, X_train, epochs = num_it, batch_size = 16, shuffle = True, validation_data = (X_noisy_test, X_test), callbacks = [hist, checkpointer])
# Out:
# Train on 400 samples, validate on 100 samples
# Epoch 1/300
# 400/400 [==============================] - 51s 128ms/step - loss: 0.0117 - val_loss: 0.0121
# Epoch 2/300
# 400/400 [==============================] - 39s 98ms/step - loss: 0.0117 - val_loss: 0.0121
# Epoch 3/300
# 400/400 [==============================] - 39s 99ms/step - loss: 0.0116 - val_loss: 0.0121
# Epoch 4/300
# 400/400 [==============================] - 40s 99ms/step - loss: 0.0116 - val_loss: 0.0121
# Epoch 5/300
# 400/400 [==============================] - 40s 99ms/step - loss: 0.0116 - val_loss: 0.0121
# Epoch 6/300
# 400/400 [==============================] - 40s 99ms/step - loss: 0.0116 - val_loss: 0.0121
# Epoch 7/300
# 400/400 [==============================] - 39s 99ms/step - loss: 0.0116 - val_loss: 0.0121
# Epoch 8/300
# 400/400 [==============================] - 39s 99ms/step - loss: 0.0116 - val_loss: 0.0121
# Epoch 9/300
# 400/400 [==============================] - 40s 99ms/step - loss: 0.0116 - val_loss: 0.0121
# Epoch 10/300
# 400/400 [==============================] - 40s 100ms/step - loss: 0.0116 - val_loss: 0.0121
# Epoch 11/300
# 400/400 [==============================] - 40s 99ms/step - loss: 0.0116 - val_loss: 0.0121
# Epoch 12/300
# 400/400 [==============================] - 40s 99ms/step - loss: 0.0116 - val_loss: 0.0121
# Epoch 13/300
# 400/400 [==============================] - 40s 99ms/step - loss: 0.0116 - val_loss: 0.0120
# Epoch 14/300
# 400/400 [==============================] - 40s 99ms/step - loss: 0.0116 - val_loss: 0.0120
# Epoch 15/300
# 400/400 [==============================] - 40s 99ms/step - loss: 0.0116 - val_loss: 0.0120
# Epoch 16/300
# 400/400 [==============================] - 40s 99ms/step - loss: 0.0116 - val_loss: 0.0120
# Epoch 17/300
# 400/400 [==============================] - 40s 99ms/step - loss: 0.0116 - val_loss: 0.0120
# Epoch 18/300
# 400/400 [==============================] - 40s 99ms/step - loss: 0.0116 - val_loss: 0.0120
# Epoch 19/300
# 400/400 [==============================] - 40s 99ms/step - loss: 0.0116 - val_loss: 0.0120
# Epoch 20/300
# 400/400 [==============================] - 40s 99ms/step - loss: 0.0116 - val_loss: 0.0120
# Epoch 21/300
# 400/400 [==============================] - 40s 100ms/step - loss: 0.0116 - val_loss: 0.0120
# Epoch 22/300
# 400/400 [==============================] - 40s 99ms/step - loss: 0.0116 - val_loss: 0.0120
# Epoch 23/300
# 400/400 [==============================] - 40s 99ms/step - loss: 0.0116 - val_loss: 0.0120
# Epoch 24/300
# 400/400 [==============================] - 40s 99ms/step - loss: 0.0116 - val_loss: 0.0120
# Epoch 25/300
# 400/400 [==============================] - 40s 99ms/step - loss: 0.0116 - val_loss: 0.0120
# Epoch 26/300
# 400/400 [==============================] - 39s 99ms/step - loss: 0.0116 - val_loss: 0.0120
# Epoch 27/300
# 400/400 [==============================] - 40s 99ms/step - loss: 0.0116 - val_loss: 0.0120
# Epoch 28/300
# 400/400 [==============================] - 40s 99ms/step - loss: 0.0116 - val_loss: 0.0120
# Epoch 29/300
# 400/400 [==============================] - 40s 99ms/step - loss: 0.0116 - val_loss: 0.0120
# Epoch 30/300
# 400/400 [==============================] - 40s 99ms/step - loss: 0.0115 - val_loss: 0.0120
# Epoch 31/300
# 400/400 [==============================] - 40s 99ms/step - loss: 0.0115 - val_loss: 0.0120
# Epoch 32/300
# 400/400 [==============================] - 40s 99ms/step - loss: 0.0115 - val_loss: 0.0120
# Epoch 33/300
# 400/400 [==============================] - 40s 100ms/step - loss: 0.0115 - val_loss: 0.0120
# Epoch 34/300
# 400/400 [==============================] - 40s 99ms/step - loss: 0.0115 - val_loss: 0.0120
# Epoch 35/300
# 400/400 [==============================] - 40s 99ms/step - loss: 0.0115 - val_loss: 0.0120
# Epoch 36/300
# 400/400 [==============================] - 40s 99ms/step - loss: 0.0115 - val_loss: 0.0120
# Epoch 37/300
# 400/400 [==============================] - 40s 99ms/step - loss: 0.0115 - val_loss: 0.0120
# Epoch 38/300
# 400/400 [==============================] - 40s 99ms/step - loss: 0.0115 - val_loss: 0.0119
# Epoch 39/300
# 400/400 [==============================] - 39s 99ms/step - loss: 0.0115 - val_loss: 0.0119
# Epoch 40/300
# 400/400 [==============================] - 40s 99ms/step - loss: 0.0115 - val_loss: 0.0119
# Epoch 41/300
# 400/400 [==============================] - 39s 99ms/step - loss: 0.0115 - val_loss: 0.0119
# Epoch 42/300
# 400/400 [==============================] - 40s 99ms/step - loss: 0.0115 - val_loss: 0.0119
# Epoch 43/300
# 400/400 [==============================] - 40s 99ms/step - loss: 0.0115 - val_loss: 0.0119
# Epoch 44/300
# 400/400 [==============================] - 40s 100ms/step - loss: 0.0115 - val_loss: 0.0119
# Epoch 45/300
# 400/400 [==============================] - 40s 99ms/step - loss: 0.0115 - val_loss: 0.0119
# Epoch 46/300
# 400/400 [==============================] - 39s 99ms/step - loss: 0.0115 - val_loss: 0.0119
# Epoch 47/300
# 400/400 [==============================] - 40s 99ms/step - loss: 0.0115 - val_loss: 0.0119
# Epoch 48/300
# 400/400 [==============================] - 40s 99ms/step - loss: 0.0115 - val_loss: 0.0119
# Epoch 49/300
# 400/400 [==============================] - 39s 99ms/step - loss: 0.0115 - val_loss: 0.0119
# Epoch 50/300
# 400/400 [==============================] - 40s 99ms/step - loss: 0.0115 - val_loss: 0.0119
# Epoch 51/300
# 400/400 [==============================] - 39s 99ms/step - loss: 0.0115 - val_loss: 0.0119
# Epoch 52/300
# 400/400 [==============================] - 39s 99ms/step - loss: 0.0115 - val_loss: 0.0119
# Epoch 53/300
# 400/400 [==============================] - 40s 99ms/step - loss: 0.0115 - val_loss: 0.0119
# Epoch 54/300
# 400/400 [==============================] - 40s 99ms/step - loss: 0.0115 - val_loss: 0.0119
# Epoch 55/300
# 400/400 [==============================] - 40s 99ms/step - loss: 0.0115 - val_loss: 0.0119
# Epoch 56/300
# 400/400 [==============================] - 40s 99ms/step - loss: 0.0114 - val_loss: 0.0119
# Epoch 57/300
# 400/400 [==============================] - 40s 99ms/step - loss: 0.0114 - val_loss: 0.0119
# Epoch 58/300
# 400/400 [==============================] - 39s 99ms/step - loss: 0.0114 - val_loss: 0.0119
# Epoch 59/300
# 400/400 [==============================] - 39s 99ms/step - loss: 0.0114 - val_loss: 0.0119
# Epoch 60/300
# 400/400 [==============================] - 39s 99ms/step - loss: 0.0114 - val_loss: 0.0119
# Epoch 61/300
# 400/400 [==============================] - 39s 99ms/step - loss: 0.0114 - val_loss: 0.0119
# Epoch 62/300
# 400/400 [==============================] - 39s 99ms/step - loss: 0.0114 - val_loss: 0.0119
# Epoch 63/300
# 400/400 [==============================] - 39s 99ms/step - loss: 0.0114 - val_loss: 0.0119
# Epoch 64/300
# 400/400 [==============================] - 40s 99ms/step - loss: 0.0114 - val_loss: 0.0119
# Epoch 65/300
# 400/400 [==============================] - 40s 99ms/step - loss: 0.0114 - val_loss: 0.0119
# Epoch 66/300
# 400/400 [==============================] - 40s 99ms/step - loss: 0.0114 - val_loss: 0.0118
# Epoch 67/300
# 400/400 [==============================] - 40s 100ms/step - loss: 0.0114 - val_loss: 0.0118
# Epoch 68/300
# 400/400 [==============================] - 40s 99ms/step - loss: 0.0114 - val_loss: 0.0118
# Epoch 69/300
# 400/400 [==============================] - 40s 99ms/step - loss: 0.0114 - val_loss: 0.0118
# Epoch 70/300
# 400/400 [==============================] - 40s 99ms/step - loss: 0.0114 - val_loss: 0.0118
# Epoch 71/300
# 400/400 [==============================] - 40s 99ms/step - loss: 0.0114 - val_loss: 0.0118
# Epoch 72/300
# 400/400 [==============================] - 40s 99ms/step - loss: 0.0114 - val_loss: 0.0118
# Epoch 73/300
# 400/400 [==============================] - 40s 99ms/step - loss: 0.0114 - val_loss: 0.0118
# Epoch 74/300
# 400/400 [==============================] - 40s 99ms/step - loss: 0.0114 - val_loss: 0.0118
# Epoch 75/300
# 400/400 [==============================] - 40s 99ms/step - loss: 0.0114 - val_loss: 0.0118
# Epoch 76/300
# 400/400 [==============================] - 40s 99ms/step - loss: 0.0114 - val_loss: 0.0118
# Epoch 77/300
# 400/400 [==============================] - 39s 99ms/step - loss: 0.0114 - val_loss: 0.0118
# Epoch 78/300
# 400/400 [==============================] - 40s 99ms/step - loss: 0.0114 - val_loss: 0.0118
# Epoch 79/300
# 400/400 [==============================] - 40s 100ms/step - loss: 0.0114 - val_loss: 0.0118
# Epoch 80/300
# 400/400 [==============================] - 40s 100ms/step - loss: 0.0114 - val_loss: 0.0118
# Epoch 81/300
# 400/400 [==============================] - 40s 100ms/step - loss: 0.0114 - val_loss: 0.0118
# Epoch 82/300
# 400/400 [==============================] - 40s 100ms/step - loss: 0.0114 - val_loss: 0.0118
# Epoch 83/300
# 400/400 [==============================] - 40s 100ms/step - loss: 0.0114 - val_loss: 0.0118
# Epoch 84/300
# 400/400 [==============================] - 40s 100ms/step - loss: 0.0114 - val_loss: 0.0118
# Epoch 85/300
# 400/400 [==============================] - 40s 99ms/step - loss: 0.0113 - val_loss: 0.0118
# Epoch 86/300
# 400/400 [==============================] - 39s 99ms/step - loss: 0.0113 - val_loss: 0.0118
# Epoch 87/300
# 400/400 [==============================] - 39s 99ms/step - loss: 0.0113 - val_loss: 0.0118
# Epoch 88/300
# 400/400 [==============================] - 39s 99ms/step - loss: 0.0113 - val_loss: 0.0118
# Epoch 89/300
# 400/400 [==============================] - 40s 99ms/step - loss: 0.0113 - val_loss: 0.0118
# Epoch 90/300
# 400/400 [==============================] - 39s 99ms/step - loss: 0.0113 - val_loss: 0.0118
# Epoch 91/300
# 400/400 [==============================] - 39s 99ms/step - loss: 0.0113 - val_loss: 0.0118
# Epoch 92/300
# 400/400 [==============================] - 39s 99ms/step - loss: 0.0113 - val_loss: 0.0117
# Epoch 93/300
# 400/400 [==============================] - 39s 99ms/step - loss: 0.0113 - val_loss: 0.0117
# Epoch 94/300
# 400/400 [==============================] - 39s 99ms/step - loss: 0.0113 - val_loss: 0.0117
# Epoch 95/300
# 400/400 [==============================] - 40s 99ms/step - loss: 0.0113 - val_loss: 0.0117
# Epoch 96/300
# 400/400 [==============================] - 40s 99ms/step - loss: 0.0113 - val_loss: 0.0117
# Epoch 97/300
# 400/400 [==============================] - 40s 100ms/step - loss: 0.0113 - val_loss: 0.0117
# Epoch 98/300
# 400/400 [==============================] - 40s 100ms/step - loss: 0.0113 - val_loss: 0.0117
# Epoch 99/300
# 400/400 [==============================] - 40s 100ms/step - loss: 0.0113 - val_loss: 0.0117
# Epoch 100/300
# 400/400 [==============================] - 40s 100ms/step - loss: 0.0113 - val_loss: 0.0117
# Epoch 101/300
# 400/400 [==============================] - 40s 100ms/step - loss: 0.0113 - val_loss: 0.0117
# Epoch 102/300
# 400/400 [==============================] - 40s 100ms/step - loss: 0.0113 - val_loss: 0.0117
# Epoch 103/300
# 400/400 [==============================] - 40s 100ms/step - loss: 0.0113 - val_loss: 0.0117
# Epoch 104/300
# 400/400 [==============================] - 40s 100ms/step - loss: 0.0113 - val_loss: 0.0117
# Epoch 105/300
# 400/400 [==============================] - 40s 100ms/step - loss: 0.0113 - val_loss: 0.0117
# Epoch 106/300
# 400/400 [==============================] - 40s 100ms/step - loss: 0.0113 - val_loss: 0.0117
# Epoch 107/300
# 400/400 [==============================] - 41s 101ms/step - loss: 0.0113 - val_loss: 0.0117
# Epoch 108/300
# 400/400 [==============================] - 41s 102ms/step - loss: 0.0113 - val_loss: 0.0117
# Epoch 109/300
# 400/400 [==============================] - 41s 101ms/step - loss: 0.0113 - val_loss: 0.0117
# Epoch 110/300
# 400/400 [==============================] - 40s 101ms/step - loss: 0.0113 - val_loss: 0.0117
# Epoch 111/300
# 400/400 [==============================] - 40s 100ms/step - loss: 0.0113 - val_loss: 0.0117
# Epoch 112/300
# 400/400 [==============================] - 40s 100ms/step - loss: 0.0113 - val_loss: 0.0117
# Epoch 113/300
# 400/400 [==============================] - 40s 101ms/step - loss: 0.0113 - val_loss: 0.0117
# Epoch 114/300
# 400/400 [==============================] - 40s 101ms/step - loss: 0.0113 - val_loss: 0.0117
# Epoch 115/300
# 400/400 [==============================] - 41s 101ms/step - loss: 0.0112 - val_loss: 0.0117
# Epoch 116/300
# 400/400 [==============================] - 41s 101ms/step - loss: 0.0112 - val_loss: 0.0117
# Epoch 117/300
# 400/400 [==============================] - 41s 101ms/step - loss: 0.0112 - val_loss: 0.0117
# Epoch 118/300
# 400/400 [==============================] - 41s 101ms/step - loss: 0.0112 - val_loss: 0.0117
# Epoch 119/300
# 400/400 [==============================] - 41s 101ms/step - loss: 0.0112 - val_loss: 0.0117
# Epoch 120/300
# 400/400 [==============================] - 41s 101ms/step - loss: 0.0112 - val_loss: 0.0117
# Epoch 121/300
# 400/400 [==============================] - 41s 101ms/step - loss: 0.0112 - val_loss: 0.0116
# Epoch 122/300
# 400/400 [==============================] - 41s 101ms/step - loss: 0.0112 - val_loss: 0.0116
# Epoch 123/300
# 400/400 [==============================] - 41s 101ms/step - loss: 0.0112 - val_loss: 0.0116
# Epoch 124/300
# 400/400 [==============================] - 40s 101ms/step - loss: 0.0112 - val_loss: 0.0116
# Epoch 125/300
# 400/400 [==============================] - 41s 101ms/step - loss: 0.0112 - val_loss: 0.0116
# Epoch 126/300
# 400/400 [==============================] - 41s 101ms/step - loss: 0.0112 - val_loss: 0.0116
# Epoch 127/300
# 400/400 [==============================] - 40s 101ms/step - loss: 0.0112 - val_loss: 0.0116
# Epoch 128/300
# 400/400 [==============================] - 40s 100ms/step - loss: 0.0112 - val_loss: 0.0116
# Epoch 129/300
# 400/400 [==============================] - 39s 99ms/step - loss: 0.0112 - val_loss: 0.0116
# Epoch 130/300
# 400/400 [==============================] - 40s 99ms/step - loss: 0.0112 - val_loss: 0.0116
# Epoch 131/300
# 400/400 [==============================] - 40s 99ms/step - loss: 0.0112 - val_loss: 0.0116
# Epoch 132/300
# 400/400 [==============================] - 40s 99ms/step - loss: 0.0112 - val_loss: 0.0116
# Epoch 133/300
# 400/400 [==============================] - 40s 99ms/step - loss: 0.0112 - val_loss: 0.0116
# Epoch 134/300
# 400/400 [==============================] - 40s 99ms/step - loss: 0.0112 - val_loss: 0.0116
# Epoch 135/300
# 400/400 [==============================] - 40s 99ms/step - loss: 0.0112 - val_loss: 0.0116
# Epoch 136/300
# 400/400 [==============================] - 39s 99ms/step - loss: 0.0112 - val_loss: 0.0116
# Epoch 137/300
# 400/400 [==============================] - 40s 99ms/step - loss: 0.0112 - val_loss: 0.0116
# Epoch 138/300
# 400/400 [==============================] - 39s 99ms/step - loss: 0.0112 - val_loss: 0.0116
# Epoch 139/300
# 400/400 [==============================] - 39s 99ms/step - loss: 0.0112 - val_loss: 0.0116
# Epoch 140/300
# 400/400 [==============================] - 40s 99ms/step - loss: 0.0112 - val_loss: 0.0116
# Epoch 141/300
# 400/400 [==============================] - 39s 99ms/step - loss: 0.0112 - val_loss: 0.0116
# Epoch 142/300
# 400/400 [==============================] - 39s 99ms/step - loss: 0.0112 - val_loss: 0.0116
# Epoch 143/300
# 400/400 [==============================] - 40s 99ms/step - loss: 0.0112 - val_loss: 0.0116
# Epoch 144/300
# 400/400 [==============================] - 39s 99ms/step - loss: 0.0112 - val_loss: 0.0116
# Epoch 145/300
# 400/400 [==============================] - 39s 99ms/step - loss: 0.0112 - val_loss: 0.0116
# Epoch 146/300
# 400/400 [==============================] - 40s 99ms/step - loss: 0.0112 - val_loss: 0.0116
# Epoch 147/300
# 400/400 [==============================] - 40s 99ms/step - loss: 0.0111 - val_loss: 0.0116
# Epoch 148/300
# 400/400 [==============================] - 39s 99ms/step - loss: 0.0111 - val_loss: 0.0116
# Epoch 149/300
# 400/400 [==============================] - 40s 99ms/step - loss: 0.0111 - val_loss: 0.0116
# Epoch 150/300
# 400/400 [==============================] - 40s 100ms/step - loss: 0.0111 - val_loss: 0.0116
# Epoch 151/300
# 400/400 [==============================] - 40s 100ms/step - loss: 0.0111 - val_loss: 0.0115
# Epoch 152/300
# 400/400 [==============================] - 40s 100ms/step - loss: 0.0111 - val_loss: 0.0115
# Epoch 153/300
# 400/400 [==============================] - 40s 100ms/step - loss: 0.0111 - val_loss: 0.0115
# Epoch 154/300
# 400/400 [==============================] - 40s 100ms/step - loss: 0.0111 - val_loss: 0.0115
# Epoch 155/300
# 400/400 [==============================] - 40s 100ms/step - loss: 0.0111 - val_loss: 0.0115
# Epoch 156/300
# 400/400 [==============================] - 40s 100ms/step - loss: 0.0111 - val_loss: 0.0115
# Epoch 157/300
# 400/400 [==============================] - 40s 100ms/step - loss: 0.0111 - val_loss: 0.0115
# Epoch 158/300
# 400/400 [==============================] - 40s 100ms/step - loss: 0.0111 - val_loss: 0.0115
# Epoch 159/300
# 400/400 [==============================] - 40s 100ms/step - loss: 0.0111 - val_loss: 0.0115
# Epoch 160/300
# 400/400 [==============================] - 40s 100ms/step - loss: 0.0111 - val_loss: 0.0115
# Epoch 161/300
# 400/400 [==============================] - 40s 100ms/step - loss: 0.0111 - val_loss: 0.0115
# Epoch 162/300
# 400/400 [==============================] - 40s 100ms/step - loss: 0.0111 - val_loss: 0.0115
# Epoch 163/300
# 400/400 [==============================] - 40s 100ms/step - loss: 0.0111 - val_loss: 0.0115
# Epoch 164/300
# 400/400 [==============================] - 40s 100ms/step - loss: 0.0111 - val_loss: 0.0115
# Epoch 165/300
# 400/400 [==============================] - 40s 100ms/step - loss: 0.0111 - val_loss: 0.0115
# Epoch 166/300
# 400/400 [==============================] - 40s 100ms/step - loss: 0.0111 - val_loss: 0.0115
# Epoch 167/300
# 400/400 [==============================] - 40s 100ms/step - loss: 0.0111 - val_loss: 0.0115
# Epoch 168/300
# 400/400 [==============================] - 40s 100ms/step - loss: 0.0111 - val_loss: 0.0115
# Epoch 169/300
# 400/400 [==============================] - 40s 100ms/step - loss: 0.0111 - val_loss: 0.0115
# Epoch 170/300
# 400/400 [==============================] - 40s 100ms/step - loss: 0.0111 - val_loss: 0.0115
# Epoch 171/300
# 400/400 [==============================] - 40s 100ms/step - loss: 0.0111 - val_loss: 0.0115
# Epoch 172/300
# 400/400 [==============================] - 40s 100ms/step - loss: 0.0111 - val_loss: 0.0115
# Epoch 173/300
# 400/400 [==============================] - 40s 99ms/step - loss: 0.0111 - val_loss: 0.0115
# Epoch 174/300
# 400/400 [==============================] - 40s 99ms/step - loss: 0.0111 - val_loss: 0.0115
# Epoch 175/300
# 400/400 [==============================] - 40s 99ms/step - loss: 0.0111 - val_loss: 0.0115
# Epoch 176/300
# 400/400 [==============================] - 39s 99ms/step - loss: 0.0111 - val_loss: 0.0115
# Epoch 177/300
# 400/400 [==============================] - 40s 99ms/step - loss: 0.0111 - val_loss: 0.0115
# Epoch 178/300
# 400/400 [==============================] - 40s 99ms/step - loss: 0.0111 - val_loss: 0.0115
# Epoch 179/300
# 400/400 [==============================] - 40s 99ms/step - loss: 0.0111 - val_loss: 0.0115
# Epoch 180/300
# 400/400 [==============================] - 39s 99ms/step - loss: 0.0111 - val_loss: 0.0115
# Epoch 181/300
# 400/400 [==============================] - 40s 99ms/step - loss: 0.0111 - val_loss: 0.0115
# Epoch 182/300
# 400/400 [==============================] - 39s 99ms/step - loss: 0.0111 - val_loss: 0.0115
# Epoch 183/300
# 400/400 [==============================] - 40s 99ms/step - loss: 0.0110 - val_loss: 0.0115
# Epoch 184/300
# 400/400 [==============================] - 39s 99ms/step - loss: 0.0110 - val_loss: 0.0114
# Epoch 185/300
# 400/400 [==============================] - 40s 99ms/step - loss: 0.0110 - val_loss: 0.0114
# Epoch 186/300
# 400/400 [==============================] - 40s 99ms/step - loss: 0.0110 - val_loss: 0.0114
# Epoch 187/300
# 400/400 [==============================] - 39s 99ms/step - loss: 0.0110 - val_loss: 0.0114
# Epoch 188/300
# 400/400 [==============================] - 39s 98ms/step - loss: 0.0110 - val_loss: 0.0114
# Epoch 189/300
# 400/400 [==============================] - 40s 100ms/step - loss: 0.0110 - val_loss: 0.0114
# Epoch 190/300
# 400/400 [==============================] - 40s 100ms/step - loss: 0.0110 - val_loss: 0.0114
# Epoch 191/300
# 400/400 [==============================] - 40s 100ms/step - loss: 0.0110 - val_loss: 0.0114
# Epoch 192/300
# 400/400 [==============================] - 40s 100ms/step - loss: 0.0110 - val_loss: 0.0114
# Epoch 193/300
# 400/400 [==============================] - 40s 100ms/step - loss: 0.0110 - val_loss: 0.0114
# Epoch 194/300
# 400/400 [==============================] - 40s 100ms/step - loss: 0.0110 - val_loss: 0.0114
# Epoch 195/300
# 400/400 [==============================] - 40s 100ms/step - loss: 0.0110 - val_loss: 0.0114
# Epoch 196/300
# 400/400 [==============================] - 40s 100ms/step - loss: 0.0110 - val_loss: 0.0114
# Epoch 197/300
# 400/400 [==============================] - 40s 100ms/step - loss: 0.0110 - val_loss: 0.0114
# Epoch 198/300
# 400/400 [==============================] - 40s 100ms/step - loss: 0.0110 - val_loss: 0.0114
# Epoch 199/300
# 400/400 [==============================] - 40s 100ms/step - loss: 0.0110 - val_loss: 0.0114
# Epoch 200/300
# 400/400 [==============================] - 40s 100ms/step - loss: 0.0110 - val_loss: 0.0114
# Epoch 201/300
# 400/400 [==============================] - 40s 100ms/step - loss: 0.0110 - val_loss: 0.0114
# Epoch 202/300
# 400/400 [==============================] - 40s 100ms/step - loss: 0.0110 - val_loss: 0.0114
# Epoch 203/300
# 400/400 [==============================] - 40s 100ms/step - loss: 0.0110 - val_loss: 0.0114
# Epoch 204/300
# 400/400 [==============================] - 40s 100ms/step - loss: 0.0110 - val_loss: 0.0114
# Epoch 205/300
# 400/400 [==============================] - 40s 100ms/step - loss: 0.0110 - val_loss: 0.0114
# Epoch 206/300
# 400/400 [==============================] - 40s 100ms/step - loss: 0.0110 - val_loss: 0.0114
# Epoch 207/300
# 400/400 [==============================] - 40s 100ms/step - loss: 0.0110 - val_loss: 0.0114
# Epoch 208/300
# 400/400 [==============================] - 40s 100ms/step - loss: 0.0110 - val_loss: 0.0114
# Epoch 209/300
# 400/400 [==============================] - 40s 100ms/step - loss: 0.0110 - val_loss: 0.0114
# Epoch 210/300
# 400/400 [==============================] - 40s 100ms/step - loss: 0.0110 - val_loss: 0.0114
# Epoch 211/300
# 400/400 [==============================] - 40s 100ms/step - loss: 0.0110 - val_loss: 0.0114
# Epoch 212/300
# 400/400 [==============================] - 40s 100ms/step - loss: 0.0110 - val_loss: 0.0114
# Epoch 213/300
# 400/400 [==============================] - 40s 100ms/step - loss: 0.0110 - val_loss: 0.0114
# Epoch 214/300
# 400/400 [==============================] - 40s 100ms/step - loss: 0.0110 - val_loss: 0.0114
# Epoch 215/300
# 400/400 [==============================] - 40s 100ms/step - loss: 0.0110 - val_loss: 0.0114
# Epoch 216/300
# 400/400 [==============================] - 40s 100ms/step - loss: 0.0110 - val_loss: 0.0114
# Epoch 217/300
# 400/400 [==============================] - 40s 100ms/step - loss: 0.0110 - val_loss: 0.0114
# Epoch 218/300
# 400/400 [==============================] - 40s 100ms/step - loss: 0.0110 - val_loss: 0.0114
# Epoch 219/300
# 400/400 [==============================] - 40s 100ms/step - loss: 0.0110 - val_loss: 0.0114
# Epoch 220/300
# 400/400 [==============================] - 40s 100ms/step - loss: 0.0110 - val_loss: 0.0113
# Epoch 221/300
# 400/400 [==============================] - 40s 100ms/step - loss: 0.0109 - val_loss: 0.0113
# Epoch 222/300
# 400/400 [==============================] - 40s 100ms/step - loss: 0.0109 - val_loss: 0.0113
# Epoch 223/300
# 400/400 [==============================] - 40s 100ms/step - loss: 0.0109 - val_loss: 0.0113
# Epoch 224/300
# 400/400 [==============================] - 40s 100ms/step - loss: 0.0109 - val_loss: 0.0113
# Epoch 225/300
# 400/400 [==============================] - 40s 100ms/step - loss: 0.0109 - val_loss: 0.0113
# Epoch 226/300
# 400/400 [==============================] - 40s 100ms/step - loss: 0.0109 - val_loss: 0.0113
# Epoch 227/300
# 400/400 [==============================] - 40s 100ms/step - loss: 0.0109 - val_loss: 0.0113
# Epoch 228/300
# 400/400 [==============================] - 40s 100ms/step - loss: 0.0109 - val_loss: 0.0113
# Epoch 229/300
# 400/400 [==============================] - 40s 100ms/step - loss: 0.0109 - val_loss: 0.0113
# Epoch 230/300
# 400/400 [==============================] - 40s 100ms/step - loss: 0.0109 - val_loss: 0.0113
# Epoch 231/300
# 400/400 [==============================] - 40s 100ms/step - loss: 0.0109 - val_loss: 0.0113
# Epoch 232/300
# 400/400 [==============================] - 40s 100ms/step - loss: 0.0109 - val_loss: 0.0113
# Epoch 233/300
# 400/400 [==============================] - 40s 100ms/step - loss: 0.0109 - val_loss: 0.0113
# Epoch 234/300
# 400/400 [==============================] - 40s 100ms/step - loss: 0.0109 - val_loss: 0.0113
# Epoch 235/300
# 400/400 [==============================] - 40s 100ms/step - loss: 0.0109 - val_loss: 0.0113
# Epoch 236/300
# 400/400 [==============================] - 40s 100ms/step - loss: 0.0109 - val_loss: 0.0113
# Epoch 237/300
# 400/400 [==============================] - 40s 100ms/step - loss: 0.0109 - val_loss: 0.0113
# Epoch 238/300
# 400/400 [==============================] - 40s 100ms/step - loss: 0.0109 - val_loss: 0.0113
# Epoch 239/300
# 400/400 [==============================] - 40s 100ms/step - loss: 0.0109 - val_loss: 0.0113
# Epoch 240/300
# 400/400 [==============================] - 40s 100ms/step - loss: 0.0109 - val_loss: 0.0113
# Epoch 241/300
# 400/400 [==============================] - 40s 100ms/step - loss: 0.0109 - val_loss: 0.0113
# Epoch 242/300
# 400/400 [==============================] - 40s 100ms/step - loss: 0.0109 - val_loss: 0.0113
# Epoch 243/300
# 400/400 [==============================] - 40s 100ms/step - loss: 0.0109 - val_loss: 0.0113
# Epoch 244/300
# 400/400 [==============================] - 40s 100ms/step - loss: 0.0109 - val_loss: 0.0113
# Epoch 245/300
# 400/400 [==============================] - 40s 100ms/step - loss: 0.0109 - val_loss: 0.0113
# Epoch 246/300
# 400/400 [==============================] - 40s 100ms/step - loss: 0.0109 - val_loss: 0.0113
# Epoch 247/300
# 400/400 [==============================] - 41s 102ms/step - loss: 0.0109 - val_loss: 0.0113
# Epoch 248/300
# 400/400 [==============================] - 41s 102ms/step - loss: 0.0109 - val_loss: 0.0113
# Epoch 249/300
# 400/400 [==============================] - 40s 101ms/step - loss: 0.0109 - val_loss: 0.0113
# Epoch 250/300
# 400/400 [==============================] - 40s 101ms/step - loss: 0.0109 - val_loss: 0.0113
# Epoch 251/300
# 400/400 [==============================] - 40s 101ms/step - loss: 0.0109 - val_loss: 0.0113
# Epoch 252/300
# 400/400 [==============================] - 40s 101ms/step - loss: 0.0109 - val_loss: 0.0113
# Epoch 253/300
# 400/400 [==============================] - 40s 101ms/step - loss: 0.0109 - val_loss: 0.0113
# Epoch 254/300
# 400/400 [==============================] - 41s 101ms/step - loss: 0.0109 - val_loss: 0.0113
# Epoch 255/300
# 400/400 [==============================] - 41s 101ms/step - loss: 0.0109 - val_loss: 0.0113
# Epoch 256/300
# 400/400 [==============================] - 41s 101ms/step - loss: 0.0109 - val_loss: 0.0113
# Epoch 257/300
# 400/400 [==============================] - 41s 101ms/step - loss: 0.0109 - val_loss: 0.0113
# Epoch 258/300
# 400/400 [==============================] - 41s 101ms/step - loss: 0.0109 - val_loss: 0.0112
# Epoch 259/300
# 400/400 [==============================] - 41s 101ms/step - loss: 0.0109 - val_loss: 0.0112
# Epoch 260/300
# 400/400 [==============================] - 41s 101ms/step - loss: 0.0109 - val_loss: 0.0112
# Epoch 261/300
# 400/400 [==============================] - 41s 101ms/step - loss: 0.0109 - val_loss: 0.0112
# Epoch 262/300
# 400/400 [==============================] - 41s 101ms/step - loss: 0.0109 - val_loss: 0.0112
# Epoch 263/300
# 400/400 [==============================] - 41s 102ms/step - loss: 0.0109 - val_loss: 0.0112
# Epoch 264/300
# 400/400 [==============================] - 41s 101ms/step - loss: 0.0108 - val_loss: 0.0112
# Epoch 265/300
# 400/400 [==============================] - 41s 102ms/step - loss: 0.0108 - val_loss: 0.0112
# Epoch 266/300
# 400/400 [==============================] - 41s 101ms/step - loss: 0.0108 - val_loss: 0.0112
# Epoch 267/300
# 400/400 [==============================] - 40s 101ms/step - loss: 0.0108 - val_loss: 0.0112
# Epoch 268/300
# 400/400 [==============================] - 41s 101ms/step - loss: 0.0108 - val_loss: 0.0112
# Epoch 269/300
# 400/400 [==============================] - 40s 101ms/step - loss: 0.0108 - val_loss: 0.0112
# Epoch 270/300
# 400/400 [==============================] - 40s 101ms/step - loss: 0.0108 - val_loss: 0.0112
# Epoch 271/300
# 400/400 [==============================] - 41s 101ms/step - loss: 0.0108 - val_loss: 0.0112
# Epoch 272/300
# 400/400 [==============================] - 41s 101ms/step - loss: 0.0108 - val_loss: 0.0112
# Epoch 273/300
# 400/400 [==============================] - 41s 101ms/step - loss: 0.0108 - val_loss: 0.0112
# Epoch 274/300
# 400/400 [==============================] - 41s 102ms/step - loss: 0.0108 - val_loss: 0.0112
# Epoch 275/300
# 400/400 [==============================] - 41s 101ms/step - loss: 0.0108 - val_loss: 0.0112
# Epoch 276/300
# 400/400 [==============================] - 41s 101ms/step - loss: 0.0108 - val_loss: 0.0112
# Epoch 277/300
# 400/400 [==============================] - 41s 101ms/step - loss: 0.0108 - val_loss: 0.0112
# Epoch 278/300
# 400/400 [==============================] - 41s 101ms/step - loss: 0.0108 - val_loss: 0.0112
# Epoch 279/300
# 400/400 [==============================] - 41s 101ms/step - loss: 0.0108 - val_loss: 0.0112
# Epoch 280/300
# 400/400 [==============================] - 41s 101ms/step - loss: 0.0108 - val_loss: 0.0112
# Epoch 281/300
# 400/400 [==============================] - 41s 101ms/step - loss: 0.0108 - val_loss: 0.0112
# Epoch 282/300
# 400/400 [==============================] - 41s 101ms/step - loss: 0.0108 - val_loss: 0.0112
# Epoch 283/300
# 400/400 [==============================] - 40s 101ms/step - loss: 0.0108 - val_loss: 0.0112
# Epoch 284/300
# 400/400 [==============================] - 40s 101ms/step - loss: 0.0108 - val_loss: 0.0112
# Epoch 285/300
# 400/400 [==============================] - 41s 101ms/step - loss: 0.0108 - val_loss: 0.0112
# Epoch 286/300
# 400/400 [==============================] - 41s 101ms/step - loss: 0.0108 - val_loss: 0.0112
# Epoch 287/300
# 400/400 [==============================] - 41s 101ms/step - loss: 0.0108 - val_loss: 0.0112
# Epoch 288/300
# 400/400 [==============================] - 41s 101ms/step - loss: 0.0108 - val_loss: 0.0112
# Epoch 289/300
# 400/400 [==============================] - 41s 101ms/step - loss: 0.0108 - val_loss: 0.0112
# Epoch 290/300
# 400/400 [==============================] - 41s 101ms/step - loss: 0.0108 - val_loss: 0.0112
# Epoch 291/300
# 400/400 [==============================] - 41s 101ms/step - loss: 0.0108 - val_loss: 0.0112
# Epoch 292/300
# 400/400 [==============================] - 41s 101ms/step - loss: 0.0108 - val_loss: 0.0112
# Epoch 293/300
# 400/400 [==============================] - 41s 101ms/step - loss: 0.0108 - val_loss: 0.0112
# Epoch 294/300
# 400/400 [==============================] - 41s 101ms/step - loss: 0.0108 - val_loss: 0.0112
# Epoch 295/300
# 400/400 [==============================] - 41s 101ms/step - loss: 0.0108 - val_loss: 0.0112
# Epoch 296/300
# 400/400 [==============================] - 41s 101ms/step - loss: 0.0108 - val_loss: 0.0112
# Epoch 297/300
# 400/400 [==============================] - 40s 101ms/step - loss: 0.0108 - val_loss: 0.0112
# Epoch 298/300
# 400/400 [==============================] - 41s 101ms/step - loss: 0.0108 - val_loss: 0.0112
# Epoch 299/300
# 400/400 [==============================] - 41s 101ms/step - loss: 0.0108 - val_loss: 0.0112
# Epoch 300/300
# 400/400 [==============================] - 41s 102ms/step - loss: 0.0108 - val_loss: 0.0112

# %% [markdown]
# Print the keys of the history callback to see where my losses are.

# %%
print(hist.history.keys())
# Out:
# dict_keys(['val_loss', 'loss'])

# %% [markdown]
# Plot the training and test history.
#
# ## Comment on the losses values
#
# The train loss starts higher than the test loss, although not by a great margin. Then they cross and finally the training loss is a bit lower than the test loss.
#
# This looks weird at first. For starters, this can be caused by dropout, by BatchNorm or some other regularization techniques. This is not the case. The last cause of this can be the mini batches. The parameters of the network are updated after every mini batch. Therefore for every mini batch my network is slightly better than before and the loss, which is averaged for all the mini batches in an epoch, is slightly better than the test loss.
#
# Then, if the machine is constantly improving and does not overfit, the gap between the network's average performance in an epoch and its performance at the end of an epoch is translated into the gap between training and validation scores - in favor of the validation scores.
#
# Considering minor variations that result from the random process of sample generation (even if data is generated only once, but especially if it is generated anew for each epoch).
#
# Therefore, I can confidently state that I'm not overfitting. I would if I had enough iterations and parameters to capture the whole dataset.
#
# [Source](https://datascience.stackexchange.com/questions/32927/understanding-lstm-behaviour-validation-loss-smaller-than-training-loss-through)

# %%
plt.figure();
plt.title("Loss (MSE) per epoch");
plt.plot(range(num_it), list(hist.history.values())[0], label = "test loss");
plt.plot(range(num_it), list(hist.history.values())[1], label = "train loss");
plt.legend();

# %%
X_decoded = big_u.predict(X_noisy_val)

# %%
n = 5
plot_some_pics(n, X_decoded)
