# %% [markdown]
# <a href="https://colab.research.google.com/github/DrAlexSanz/Image-SR/blob/master/SR_HUGE_Unet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# This notebook implements the deeper UNET architecture. It is applied as a deblurring autoencoder as an intermediate way to work on the "deblurrer" and the image super-resolution.
#
# It works on a 100x100 patch of images taken from the flickr 8k dataset. I could have done it for bigger images but I can only run this on colab because my computer is what it is. On the other hand, 100x100 is a reasonable size, it's small enough to run in a reasonable time but it's big enough for a realistic problem. It's one order of magnitude bigger in each dimension than the mnist equivalent (what I called small unet). It also has the advantage that the dataset fits in memory and I don't have to develop a custom Image data generator. This is the next thing I will do.

# %% [markdown]
# First import things that I will need and a bit more that I may need later.

# %%
import numpy as np
import os, shutil
from keras import backend as K
from keras.layers import Input, Dense, Conv2D, MaxPooling2D, UpSampling2D, Add, BatchNormalization, Concatenate, Conv2DTranspose, ZeroPadding2D, Cropping2D
from keras.models import Model, load_model
from keras.utils import plot_model
from keras.optimizers import Adam, Adadelta, Adagrad
from keras.callbacks import History, ModelCheckpoint
import matplotlib.pyplot as plt
import glob
import cv2
from PIL import Image, ImageFilter
from scipy.ndimage.filters import gaussian_filter

K.set_image_data_format("channels_last")
# Out:
# Using TensorFlow backend.

# %% [markdown]
# Get the auxiliary functions that I developed from my colab.

# %%
# !wget https://raw.githubusercontent.com/DrAlexSanz/Image-SR/master/big_UNET.py

# !wget https://raw.githubusercontent.com/DrAlexSanz/Image-SR/master/huge_UNET.py
from huge_UNET import *
# Out:
# --2019-10-13 13:16:58--  https://raw.githubusercontent.com/DrAlexSanz/Image-SR/master/huge_UNET.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 11206 (11K) [text/plain]
# Saving to: ‘huge_UNET.py’
#
# huge_UNET.py        100%[===================>]  10.94K  --.-KB/s    in 0s
#
# 2019-10-13 13:16:58 (122 MB/s) - ‘huge_UNET.py’ saved [11206/11206]

# %% [markdown]
# Mount my google drive to access my dataset.

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount = True)
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %% [markdown]
# As I said, the function loads the dataset into a numpy vector (tensor). It takes the picture, crops a 300x300 patch from it and saves it in the X array. The patch is always the top left corner, as explained inside, for simplicity. Could be randomly taken and I will probably implement this in the Data Generator. In any case, the patch is big enough to capture a reasonable proportion of the image. Not a lot of information is lost. This function is not the fastest one, but I only run it the first time and then I save the vector. Loading the array is very fast. Comment or uncomment the lines below as needed.

# %%
path_flickr = "/content/drive/My Drive/flickr"

# %% [markdown]
# Comment or uncomment as needed. Or just run the relevant cells.

# %%
X_big = load_imgs_to_array(path_flickr)

# %%
np.save("/content/drive/My Drive/Image-SR/pic_big.npy", X_big)

# %%
X_big = np.load("/content/drive/My Drive/Image-SR/pic_big.npy") # Very fast once it is created

# %% [markdown]
# Make sure I loaded what I wanted to load.

# %%
np.array(X_big).shape
# Out:
# (600, 300, 300, 3)

# %% [markdown]
# Make the train, test and validation datasets. The dataset is already random as far as I can see looking at the pictures. I take the first 400 pictures as train set, then 100 as a test set and the last 100 as a validation set, to predict.
#
# Some people may argue that 400 pictures are not too many. I could do more, of course, but then it takes longer to run. As I said, I wanted to find a compromise between a realistic training set and a fast one. I don't get anything from having the script run for two weeks.

# %%
X_train, X_val, X_test = split_data(X_big)

# %% [markdown]
# Make sure I split the data properly.

# %%
X_train.shape
# Out:
# (400, 300, 300, 3)

# %% [markdown]
# Thake the ground truths and add the noise to create the inputs. I think 0.15 as a factor is reasonable. It's random gaussian noise (not blurr) that is added to the picture. After normalizing and adding the noise I clip it at 1 just for a better convergence. It should converge also If I skip this step but this will most likely make it faster.
#
# At a 0.5 noise factor the problem is much harder. The epochs, learing rate and the model should be refined.

# %% [markdown]
# Loading the images as a vector is easier. It's important to apply the blur while they are images instead of np arrays. Otherwise it does a convolution on all the channels at the same time, not a 2D filter for each channel.

# %%
X_LR = load_imgs_low_res(path_flickr)

# %%
np.save("/content/drive/My Drive/Image-SR/LR_big.npy", X_LR)

# %%
X_LR = np.load("/content/drive/My Drive/Image-SR/LR_big.npy")

# %%
X_LR_train, X_LR_val, X_LR_test = split_data(X_LR)

# %% [markdown]
# I will show a few images to check that everything works.

# %%
n = 5
plot_some_pics(n, X_LR_test)

# %% [markdown]
# Make sure that I have some aliasing.

# %%
plt.figure(figsize = (15, 10))
plt.imshow(X_LR_test[13])

# %% [markdown]
# Same as before, use the

# %% [markdown]
# I define the magnitudes of the different tensor dimensions and call the definition function. Plot the summary.
#
# In the definition, the BatchNorm layers are commented out. I found out that they don't result on a significant improvement on convergence. Therefore leaving them active won't be too advantageous.

# %%
width = X_train.shape[1]
height = X_train.shape[2]
n_channels = X_train.shape[3]

big_u = Huge_UNET(width, height, n_channels)
big_u.summary()
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 300, 300, 3)  0
# __________________________________________________________________________________________________
# C1 (Conv2D)                     (None, 300, 300, 64) 1792        input_1[0][0]
# __________________________________________________________________________________________________
# C2 (Conv2D)                     (None, 150, 150, 128 73856       C1[0][0]
# __________________________________________________________________________________________________
# C3 (Conv2D)                     (None, 75, 75, 256)  295168      C2[0][0]
# __________________________________________________________________________________________________
# C4 (Conv2D)                     (None, 38, 38, 256)  1638656     C3[0][0]
# __________________________________________________________________________________________________
# C5 (Conv2D)                     (None, 19, 19, 512)  1180160     C4[0][0]
# __________________________________________________________________________________________________
# Encoded (Conv2D)                (None, 19, 19, 1024) 525312      C5[0][0]
# __________________________________________________________________________________________________
# C5T (Conv2DTranspose)           (None, 38, 38, 1024) 9438208     Encoded[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 38, 38, 1280) 0           C5T[0][0]
#                                                                  C4[0][0]
# __________________________________________________________________________________________________
# C4T (Conv2DTranspose)           (None, 76, 76, 512)  5898752     concatenate_1[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_1 (ZeroPadding2D (None, 76, 76, 256)  0           C3[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 76, 76, 768)  0           C4T[0][0]
#                                                                  zero_padding2d_1[0][0]
# __________________________________________________________________________________________________
# C3T (Conv2DTranspose)           (None, 152, 152, 256 1769728     concatenate_2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_2 (ZeroPadding2D (None, 152, 152, 128 0           C2[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 152, 152, 384 0           C3T[0][0]
#                                                                  zero_padding2d_2[0][0]
# __________________________________________________________________________________________________
# cropping2d_1 (Cropping2D)       (None, 150, 150, 384 0           concatenate_3[0][0]
# __________________________________________________________________________________________________
# C2T (Conv2DTranspose)           (None, 300, 300, 64) 221248      cropping2d_1[0][0]
# __________________________________________________________________________________________________
# C0T (Conv2D)                    (None, 300, 300, 3)  1731        C2T[0][0]
# ==================================================================================================
# Total params: 21,044,611
# Trainable params: 21,044,611
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# Plot the model to see that my connections are correct. They seem to be ok.

# %%
plot_model(big_u, to_file = "Big_Unet.png",show_shapes = True)

# %% [markdown]
# Train the model. Add the history and checkpoint callbacks. I don't want to lose 1 h of training if the session runs out. The history will be used later to plot the training process.
#
# As optimizer use Adadelta. For some reason Adam and Adagrad are not as efficient. They tend to stagnate for several iterations. The default parameters work ok with a 0.05 learning rate.
#
# I set the number of iterations to 200 or 300. You need about 200 to start seeing something reasonable in the predicted images. At the beginning they are mostly grey.
#
# As a loss function MSE is better in this case. Binary Crossentropy is ok too but there is a drawback, the function is not symmetric. Looking at the definition:
#
# $L = -\sum p\cdot log(p)$
#
# The log function is not symmetric, which translates into a general assymetry of the , so the side in which I iterate will make a difference. Besides, since I want to rebuild the picture, MSE or even MAE seem more correct from the conceptual point of view. Ideally, all the pixels would be the same after the training process.

# %%
opti = Adadelta(lr = 1) # Keras docs say leave it at 1, default.
hist = History()
path_save = "/content/drive/My Drive/Image-SR/LR_epoch_{epoch:04d}.h5" #the current one
checkpointer = ModelCheckpoint(path_save, period = 25, save_best_only = False, save_weights_only = True)
big_u.compile(optimizer = opti, loss = "mean_absolute_error") # Seems to be better than MSE according to paper from EDSRN
num_it = 300
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %% [markdown]
# Now I train the model.

# %%
big_u.fit(X_LR_train, X_train, epochs = num_it, batch_size = 16, shuffle = True, validation_data = (X_LR_test, X_test), callbacks = [hist, checkpointer])
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1033: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1020: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3005: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# Train on 400 samples, validate on 100 samples
# Epoch 1/300
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:197: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:207: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:216: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:223: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# 400/400 [==============================] - 93s 233ms/step - loss: 0.2324 - val_loss: 0.1911
# Epoch 2/300
# 400/400 [==============================] - 69s 173ms/step - loss: 0.1758 - val_loss: 0.1702
# Epoch 3/300
# 400/400 [==============================] - 69s 172ms/step - loss: 0.1391 - val_loss: 0.1189
# Epoch 4/300
# 400/400 [==============================] - 69s 172ms/step - loss: 0.1210 - val_loss: 0.1102
# Epoch 5/300
# 400/400 [==============================] - 69s 171ms/step - loss: 0.1184 - val_loss: 0.0974
# Epoch 6/300
# 400/400 [==============================] - 69s 172ms/step - loss: 0.1165 - val_loss: 0.1109
# Epoch 7/300
# 400/400 [==============================] - 69s 172ms/step - loss: 0.1079 - val_loss: 0.1119
# Epoch 8/300
# 400/400 [==============================] - 69s 171ms/step - loss: 0.1030 - val_loss: 0.0987
# Epoch 9/300
# 400/400 [==============================] - 69s 172ms/step - loss: 0.0960 - val_loss: 0.1460
# Epoch 10/300
# 400/400 [==============================] - 69s 173ms/step - loss: 0.0964 - val_loss: 0.0991
# Epoch 11/300
# 400/400 [==============================] - 69s 173ms/step - loss: 0.0899 - val_loss: 0.1053
# Epoch 12/300
# 400/400 [==============================] - 69s 173ms/step - loss: 0.0863 - val_loss: 0.0774
# 400/400 [==============================] - 69s 172ms/step - loss: 0.0368 - val_loss: 0.0359
# Epoch 295/300
# 400/400 [==============================] - 69s 173ms/step - loss: 0.0363 - val_loss: 0.0378
# Epoch 296/300
# 400/400 [==============================] - 69s 172ms/step - loss: 0.0364 - val_loss: 0.0355
# Epoch 297/300
# 400/400 [==============================] - 69s 172ms/step - loss: 0.0369 - val_loss: 0.0390
# Epoch 298/300
# 400/400 [==============================] - 69s 171ms/step - loss: 0.0364 - val_loss: 0.0376
# Epoch 299/300
# 400/400 [==============================] - 69s 172ms/step - loss: 0.0367 - val_loss: 0.0408
# Epoch 300/300
# 400/400 [==============================] - 69s 171ms/step - loss: 0.0358 - val_loss: 0.0396

# %%
big_u.save_weights("/content/drive/My Drive/Image-SR/LR_epoch_0001.h5")

# %% [markdown]
# Print the keys of the history callback to see where my losses are.

# %%
print(hist.history.keys())
# Out:
# dict_keys(['val_loss', 'loss'])

# %% [markdown]
# Plot the training and test history.
#
# ## Comment on the losses values
#
# The train loss starts higher than the test loss, although not by a great margin. Then they cross and finally the training loss is a bit lower than the test loss.
#
# This looks weird at first. For starters, this can be caused by dropout, by BatchNorm or some other regularization techniques. This is not the case. The last cause of this can be the mini batches. The parameters of the network are updated after every mini batch. Therefore for every mini batch my network is slightly better than before and the loss, which is averaged for all the mini batches in an epoch, is slightly better than the test loss.
#
# Then, if the machine is constantly improving and does not overfit, the gap between the network's average performance in an epoch and its performance at the end of an epoch is translated into the gap between training and validation scores - in favor of the validation scores.
#
# Considering minor variations that result from the random process of sample generation (even if data is generated only once, but especially if it is generated anew for each epoch).
#
# Therefore, I can confidently state that I'm not overfitting. I would if I had enough iterations and parameters to capture the whole dataset.
#
# [Source](https://datascience.stackexchange.com/questions/32927/understanding-lstm-behaviour-validation-loss-smaller-than-training-loss-through)

# %%
plt.figure();
plt.title("Loss (MAE) per epoch");
plt.plot(range(num_it), list(hist.history.values())[0], label = "test loss");
plt.plot(range(num_it), list(hist.history.values())[1], label = "train loss");
plt.legend();

# %%
X_decoded = big_u.predict(X_LR_val)

# %%
n = 5
plot_some_pics(n, X_decoded)

# %% [markdown]
# And just to see one, the net works ok-ish. Probably if I leave it for more iterations, and a bigger dataset, the MSE will be reduced. However, this takes time and space in my google drive. As they are both scarce resources I will not try to reduce the MSE even further. Rembember that for a given MAE value of ~0.03, transforming very crudely this is a ~5% error. People who read math books, don't kill me, this is a very quick conversion but it kind of works to get the order of magnitude of the error.
#
# Here I compare the real image (left) and the upsampled image (right) after 150 epochs. I could run it for another 150, but as I said it doesn't add much. The loss still decreases but the slope is much lower. The history plot shows that the loss saturates very quickly and then although it improves, it's not great. I could also set an acceptable loss and then stop automatically, but I want to have weights every 25 epochs.
#
# As shown below, the generated image doesn't look as sharp as the original one, but it doesn't look too different. It loses the comparison on the background but it doesn't look too bad.

# %%
index = 0

fig, ax = plt.subplots(1, 2)
# plt.figure(figsize = (8, 4))
plt.subplot(1, 2, 1)
plt.imshow(X_val[index])
plt.axis("off")

plt.subplot(1, 2, 2)
plt.imshow(X_decoded[index])
plt.axis("off")
# Out:
# (-0.5, 299.5, 299.5, -0.5)

# %% [markdown]
# What is very interesting is that the images generated at the early epochs are mostly grey/black. Their pixel values are close to a given value at the beginning and they are updated, it starts from 0, get close to the good value and they are fine tuned at the end. This reminds me of the way a GAN works, my 10 to @dotCSV and the pix2pix video.
#
# Let's see this.

# %% [markdown]
# Epoch 1:

# %%
big_u.load_weights("/content/drive/My Drive/Image-SR/LR_epoch_0001.h5")
X_1 = big_u.predict(X_LR_val)

# %%
index = 13

fig, ax = plt.subplots(1, 2)
# plt.figure(figsize = (8, 4))
plt.subplot(1, 2, 1)
plt.imshow(X_val[index])
plt.axis("off")

plt.subplot(1, 2, 2)
plt.imshow(X_1[index])
plt.axis("off")
# Out:
# (-0.5, 299.5, 299.5, -0.5)

# %% [markdown]
# Epoch 25:

# %%
big_u.load_weights("/content/drive/My Drive/Image-SR/LR_epoch_0025.h5")
X_25 = big_u.predict(X_LR_val)

# %%
index = 2

fig, ax = plt.subplots(1, 2)
# plt.figure(figsize = (8, 4))
plt.subplot(1, 2, 1)
plt.imshow(X_val[index])
plt.axis("off")

plt.subplot(1, 2, 2)
plt.imshow(X_25[index])
plt.axis("off")
# Out:
# (-0.5, 299.5, 299.5, -0.5)

# %% [markdown]
# Epoch 50:

# %%
big_u.load_weights("/content/drive/My Drive/Image-SR/LR_epoch_0050.h5") # It didn't overwrite this one
X_50 = big_u.predict(X_LR_val)

# %%
index = 2

fig, ax = plt.subplots(1, 2)
# plt.figure(figsize = (8, 4))
plt.subplot(1, 2, 1)
plt.imshow(X_val[index])
plt.axis("off")

plt.subplot(1, 2, 2)
plt.imshow(X_50[index])
plt.axis("off")
# Out:
# (-0.5, 299.5, 299.5, -0.5)

# %% [markdown]
# Epoch 300: The image is even better than what I had in mind.

# %%
big_u.load_weights("/content/drive/My Drive/Image-SR/LR_epoch_0300.h5")
X_300 = big_u.predict(X_LR_val)

# %%
index = 2

fig, ax = plt.subplots(1, 2)
# plt.figure(figsize = (8, 4))
plt.subplot(1, 2, 1)
plt.imshow(X_val[index])
plt.axis("off")

plt.subplot(1, 2, 2)
plt.imshow(X_300[index])
plt.axis("off")
# Out:
# (-0.5, 299.5, 299.5, -0.5)

# %% [markdown]
# And bigger, just to see the details

# %%
index = 2

fig, ax = plt.subplots(1, 2, figsize = (16,10))
# plt.figure(figsize = (8, 4))
plt.subplot(1, 2, 1)
plt.imshow(X_val[index])
plt.axis("off")

plt.subplot(1, 2, 2)
plt.imshow(X_300[index])
plt.axis("off")
# Out:
# (-0.5, 299.5, 299.5, -0.5)

# %% [markdown]
# And comparing with the input (manual downsample + upsample):

# %%
plt.figure(figsize = (7, 7))
plt.imshow(X_LR_val[index])

# %% [markdown]
# Not too bad!! The result, without being a miracle is quite acceptable considering this is such a simple model.
